# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
import google.generativeai as genai
import os

import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="google.generativeai")

os.environ["GOOGLE_API_KEY"] = "AIzaSyACJY8EF2dUJe22u0QrfhLdAenVjpBNhv0"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
def read_csvfile(filename):
    """Read CSV file with flexible path"""
    path="data"
    filepath=Path(path)
    file = pd.read_csv(filepath/filename, encoding='latin1')
    return file

# %%
def clean_column_names(df):
    df=df.copy()
    df.columns = [re.sub(r"[^0-9a-zA-Z]", "_", str(c).strip()).strip("_").lower()
                  for c in df.columns]
    return df

# %%
def clean_date_column(df, date_col):
    df=df.copy()
    for d in date_col:
        df[d]=pd.to_datetime(df[d], errors="coerce")
    return df

# %%
def filter_data(df):
    df=df.copy()
    df=df[(df["university_campus"]=="Newark") & (~df["exam_workflow_status"].isin(["Cancelled", "Duplicate"]))]
    return df

# %%
def date_range_of_data(df, start_date, end_date):
    filtered_data = df[(df["scheduled_date"]>=start_date) & (df["scheduled_date"]<=end_date)]
    exams_per_day = filtered_data.groupby("scheduled_date").size().reset_index(name="exam_count")
    return exams_per_day

# %% [markdown]
# Assumption: If number of exams is more than or equal to 15, it's considered as peak exam day

# %%
def find_peak_exam_days(df, start_date, end_date):
    exams_per_day = date_range_of_data(df, start_date, end_date)
    peak_days = exams_per_day.sort_values("exam_count", ascending=False)
    peak_days = peak_days[peak_days["exam_count"]>=15]
    return peak_days

# %%
def find_peak_exam_weekday(df, start_date, end_date):
    exams_per_day = date_range_of_data(df, start_date, end_date)       
    exams_per_day["day_of_the_week"] = exams_per_day["scheduled_date"].dt.day_name()
    peak_day_of_the_week = exams_per_day.groupby("day_of_the_week").sum("exam_count").sort_values("exam_count", ascending=False)
    return peak_day_of_the_week

# %%
def find_peak_exam_month(df, start_date, end_date):
    exams_per_day = date_range_of_data(df, start_date, end_date)       
    exams_per_day["month_of_year"] = exams_per_day["scheduled_date"].dt.month_name()
    peak_month = exams_per_day.groupby("month_of_year").sum("exam_count").sort_values("exam_count", ascending=False)
    return peak_month

# %% [markdown]
# Assumption: Each classroom can accommodate 7 students with special needs

# %%
def find_rooms_required(df, start_date, end_date):
    peak_exam_days = find_peak_exam_days(df, start_date, end_date)
    peak_exam_days["rooms_required"]= np.ceil(peak_exam_days["exam_count"]/7).astype(int)
    return peak_exam_days

# %% [markdown]
# Assumption: Each classroom needs 2 proctors at a time

# %%
def find_number_of_proctors(df, start_date, end_date):
    """
    Find number of proctors needed for the day assuming each classroom needs 2 proctors at a time
    parameters: dataframe, start date and end date of the date range you want the data of
    returns: dataframe with an additional column containing count of proctors needed
    """
    peak_days = find_rooms_required(df, start_date, end_date)
    peak_days["proctors_required"] = peak_days["rooms_required"]*2
    return peak_days

# %%
print("Welcome to Exam AI Assistant")
print("=" * 60)
#C:\Users\anush\Desktop\Misc\MS 2024\GitHub Projects\Exams Database\input\Exam_Requests.csv
csv_file = input("Enter CSV file name: ").strip()
if not csv_file:
    csv_file = "sample_data.csv"

print(f"\nLoading {csv_file}...")
df = read_csvfile(csv_file)
df = clean_column_names(df)
df = clean_date_column(df, ["scheduled_date"])
df = filter_data(df)

print(f"Loaded {len(df)} exams successfully")
print(f"Date range: {df['scheduled_date'].min().date()} to {df['scheduled_date'].max().date()}")

# Get date range for analysis
print(f"\nPlease enter the date range for analysis")
start_date = input("\nStart date (YYYY-MM-DD): ").strip()
end_date = input("End date (YYYY-MM-DD): ").strip()
# Out:
# Welcome to Exam AI Assistant
# ============================================================
# Enter CSV file name:  Exam_Requests.csv
# Loading Exam_Requests.csv...
# Loaded 2146 exams successfully
# Date range: 2024-09-12 to 2025-12-22
#
# Please enter the date range for analysis
# Start date (YYYY-MM-DD):  2024-09-01
# End date (YYYY-MM-DD):  2024-12-31

# %%
def gather_exam_statistics(df, start_date, end_date):
    """Gathers all exam data in one place"""
    
    exam_data = {
        "monthly": find_peak_exam_month(df, start_date, end_date),
        "peak_days": find_peak_exam_days(df, start_date, end_date),
        "weekdays": find_peak_exam_weekday(df, start_date, end_date),
        "proctors": find_number_of_proctors(df, start_date, end_date),
        "rooms": find_rooms_required(df, start_date, end_date),
    }
    
    return exam_data

# %%
def format_monthly_data(monthly_data):
    """Format monthly statistics as readable string"""
    return "\n".join([f"  {month}: {count} exams" for month, count in monthly_data.items()])


def format_peak_days(peak_days):
    """Format peak days as readable string"""
    return "\n".join([f"  {day.date()}: {count} exams" 
                      for day, count in peak_days[['scheduled_date', 'exam_count']].values])


def format_weekday_data(weekday_data):
    """Format weekday statistics as readable string"""
    return "\n".join([f"  {day}: {count} exams" for day, count in weekday_data.items()])


def format_resource_requirements(proctors_data, rooms_data):
    """Format resource requirements as readable string"""
    max_proctors = proctors_data["proctors_required"].max()
    max_rooms = rooms_data["rooms_required"].max()
    
    return f"""  - Max Proctors Needed: {int(max_proctors)}
    - Max Rooms Needed: {int(max_rooms)}"""

# %%
def build_gemini_prompt(question, statistics, start_date, end_date):
    """Build the prompt to send to Gemini AI"""
    
    # Format all exam related data
    monthly_str = format_monthly_data(statistics["monthly"])
    peak_days_str = format_peak_days(statistics["peak_days"])
    weekday_str = format_weekday_data(statistics["weekdays"])
    resources_str = format_resource_requirements(statistics["proctors"], statistics["rooms"])
    
    # Build the prompt
    prompt = f"""You are a Data Analyst. Use the following data context to answer the user's question.

ACTUAL DATA ANALYSIS RESULTS ({start_date} to {end_date}):

MONTHLY BREAKDOWN:
{monthly_str}

PEAK DAYS:
{peak_days_str}

WEEKDAY DISTRIBUTION:
{weekday_str}

RESOURCE REQUIREMENTS:
{resources_str}

USER QUESTION: {question}

Based on the ACTUAL DATA shown above, answer the user's question with specific numbers and recommendations."""
    
    return prompt

# %%
def ask_gemini(prompt):
    """Send prompt to Gemini and get response"""
    model = genai.GenerativeModel('gemini-flash-latest')
    response = model.generate_content(prompt)
    return response.text

# %%
def ask_gemini_about_exams(question, df, start_date, end_date):
    """Main function that coordinates all the above steps."""
    
    # Step 1: Gather statistics
    statistics = gather_exam_statistics(df, start_date, end_date)
    
    # Step 2: Build prompt
    prompt = build_gemini_prompt(question, statistics, start_date, end_date)
    
    # Step 3: Get answer from Gemini
    answer = ask_gemini(prompt)
    
    # Step 4: Return answer
    return answer

# %%
def run_interactive_chat(df, start_date, end_date):
    """Run the interactive Q&A loop"""
    
    print("\n" + "=" * 60)
    print("Ask questions about your exam data!")
    print("Type 'quit' to exit")
    print("=" * 60 + "\n")
    
    while True:
        question = input("Your question: ").strip()
        
        # Check for exit
        if question.lower() in ['quit', 'exit', 'stop']:
            print("\nExiting.....")
            break
        
        # Check for empty input
        if not question:
            print("Please enter a question.\n")
            continue
        
        # Get and display answer
        print("\nGemini is analyzing your data...\n")
        
        try:
            answer = ask_gemini_about_exams(question, df, start_date, end_date)
            print(f"Answer:\n{answer}\n")
            print("-" * 60 + "\n")
        except Exception as e:
            print(f"Error: {str(e)}")
            print("Make sure your API_KEY is set.\n")

run_interactive_chat(df, start_date, end_date)
# Out:
# ============================================================
# Ask questions about your exam data!
# Type 'quit' to exit
# ============================================================
# Your question:  Which is the peak exam month?
# Gemini is analyzing your data...
#
# Answer:
# Based on the data analysis for the period of September 1, 2024, to December 31, 2024, **December is the peak exam month.**
#
# ### Data Analysis Details:
# *   **Total Volume:** December recorded **227 exams**, making it the busiest month in the quarter. For comparison, October followed closely with 219 exams, while November had 170 and September had 58.
# *   **Concentrated Activity:** The highest volume of daily activity occurred during the third week of December. The top four busiest days of the entire period were consecutive days in December:
#     *   **December 16:** 39 exams (The absolute peak day)
#     *   **December 17:** 30 exams
#     *   **December 18:** 25 exams
#     *   **December 19:** 24 exams
# *   **Resource Demand:** During these peak periods in December, the facility reached its maximum requirement of **12 proctors** and **6 rooms**.
#
# ### Recommendations:
# 1.  **Prioritize Mid-December Staffing:** Ensure that the maximum roster of 12 proctors is scheduled and confirmed well in advance for the second and third weeks of December, particularly for the dates between Dec 16th and Dec 19th.
# 2.  **Room Allocation:** Since 6 rooms are required at peak capacity, maintenance or non-exam activities should be strictly prohibited in the testing center during the month of December to avoid scheduling conflicts.
# 3.  **Weekday Management:** While December is the peak month, **Thursday** is the overall busiest weekday (195 exams). When December dates fall on a Thursday, the facility should expect maximum throughput and should not allow overbooking.
# 4.  **Early Preparation:** There is a significant jump in volume from September (58 exams) to October (219 exams). Staffing and resource readiness should be finalized by late September to handle the high volume that remains consistent through the end of the year.
#
# ------------------------------------------------------------
# Your question:  How many proctors will be needed in the 3rd week of September?
# Gemini is analyzing your data...
#
# Answer:
# Based on the data analysis for the period of September 1, 2024, to December 31, 2024, here is the assessment for the 3rd week of September (September 15–21):
#
# ### **Data Analysis**
# *   **Monthly Volume:** September had the lowest exam volume of the entire period, with only **58 exams** total (compared to 227 in December).
# *   **Peak Day Context:** No days from the 3rd week of September appear on the "Peak Days" list. The only September date listed as a high-volume day is September 26 (the 4th week) with 18 exams.
# *   **Resource Scaling:** The maximum requirement of **12 proctors** is calculated based on the peak day of December 16, which handled 39 exams.
#
# ### **Resource Requirements for Week 3 (Sept 15–21)**
# Given that the 3rd week of September did not reach the "Peak Day" threshold (which starts at 16 exams per day), the requirements are significantly lower than the seasonal maximums:
#
# 1.  **Proctor Count:** You will likely need **3 to 5 proctors**.
#     *   *Reasoning:* Since 39 exams required 12 proctors, and the highest day in September (18 exams) would roughly require 6 proctors, the non-peak days in the 3rd week will require a smaller skeleton crew.
# 2.  **Room Count:** You will likely need **2 rooms**.
#     *   *Reasoning:* The max of 6 rooms is reserved for days with ~40 exams. With September's lower daily average, 2 rooms should be sufficient to handle the distributed load.
#
# ### **Recommendations**
# *   **Focus on Mid-Week:** According to the Weekday Distribution, **Thursday** is the busiest day overall. If you have exams scheduled on Thursday, September 19, ensure you are at the higher end of the estimate (5 proctors).
# *   **Minimal Friday Staffing:** Friday is the lowest volume day (71 exams total). You can likely operate with minimum staffing (1-2 proctors) on Friday, September 20.
# *   **Staffing Efficiency:** Because September represents only ~8.6% of the total exam volume for the period, this is an ideal time to utilize junior proctors or conduct training before the peak surge in October and December.
#
# ------------------------------------------------------------
